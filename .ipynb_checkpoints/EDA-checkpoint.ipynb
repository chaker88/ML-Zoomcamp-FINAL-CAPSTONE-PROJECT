# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pycountry
import plotly.io as pio

# %%
def data_wrangler(path):
    # Load dataset
    df = pd.read_csv(path)
    
    # Drop useless columns (update if needed)
    drop_cols = ["Unnamed: 0", "Accessibility"]
    df = df.drop(columns=[c for c in drop_cols if c in df.columns])
    
    # Drop null values and duplicates
    df = df.dropna().drop_duplicates().reset_index(drop=True)
    
    # Standardize country names (title case)
    df["Country"] = df["Country"].str.title()
    
    # Optional: common country name aliases
    alias_map = {
    "Usa": "United States",
    "Uk": "United Kingdom",
    "South Korea": "Korea, Republic of",
    "Viet Nam": "Vietnam",
    "Iran, Islamic Republic Of...": "Iran",
    "Hong Kong (S.A.R.)": "Hong Kong",
    "The Former Yugoslav Republic Of Macedonia": "North Macedonia",
    "Venezuela, Bolivarian Republic Of...": "Venezuela",
    "Democratic Republic Of The Congo": "Congo, The Democratic Republic of the",
    "Kosovo": "Kosovo",  # Pycountry may not include Kosovo officially
    "Nomadic": None,      # Not a country
    "Congo, Republic Of The...": "Congo",
    "Republic Of Korea": "Korea, Republic of",
    "Swaziland": "Eswatini",
    "Libyan Arab Jamahiriya": "Libya",
    "Palestine": "Palestine",  # May remain None if pycountry cannot resolve
    "Cape Verde": "Cabo Verde",
    "Turkey": "TUR"
    }
    df["Country"] = df["Country"].apply(lambda x: alias_map.get(x, x))
    
    # Safe ISO-3 mapping
    def safe_iso3(name):
        try:
            return pycountry.countries.lookup(name).alpha_3
        except LookupError:
            return None
    
    df["Country_ISO3"] = df["Country"].apply(safe_iso3)
    
    return df

# %%
path = "dataset/stackoverflow_full.csv"
df = data_wrangler(path)
df.head()
# Out:
#    Age        EdLevel  Employment Gender MentalHealth MainBranch  YearsCode  \
# 0  <35         Master           1    Man           No        Dev          7
# 1  <35  Undergraduate           1    Man           No        Dev         12
# 2  <35         Master           1    Man           No        Dev         15
# 3  <35  Undergraduate           1    Man           No        Dev          9
# 4  >35            PhD           0    Man           No     NotDev         40
#
#    YearsCodePro    Country  PreviousSalary  \
# 0             4     Sweden         51552.0
# 1             5      Spain         46482.0
# 2             6    Germany         77290.0
# 3             6     Canada         46135.0
# 4            30  Singapore        160932.0
#
#                                       HaveWorkedWith  ComputerSkills  \
# 0                          C++;Python;Git;PostgreSQL               4
# 1  Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...              12
# 2             C;C++;Java;Perl;Ruby;Git;Ruby on Rails               7
# 3  Bash/Shell;HTML/CSS;JavaScript;PHP;Ruby;SQL;Gi...              13
# 4                                         C++;Python               2
#
#    Employed Country_ISO3
# 0         0          SWE
# 1         1          ESP
# 2         0          DEU
# 3         0          CAN
# 4         0          SGP

# %%
df.columns
# Out:
# Index(['Age', 'EdLevel', 'Employment', 'Gender', 'MentalHealth', 'MainBranch',
#        'YearsCode', 'YearsCodePro', 'Country', 'PreviousSalary',
#        'HaveWorkedWith', 'ComputerSkills', 'Employed', 'Country_ISO3'],
#       dtype='object')

# %% [markdown]
# ## Age

# %%
df.Age.value_counts(normalize=True).round(2).plot(kind='bar')
plt.title("Distribution of Age Category")
plt.show()

# %% [markdown]
# More than 65% of the survey participants are aged above 35 years, indicating that the dataset is predominantly composed of mid-career and senior individuals rather than early-career respondents.

# %%
# Distribution of Employment status by Age
df.groupby("Age")["Employed"].value_counts(normalize=True).round(2).unstack(fill_value=0)
# Out:
# Employed     0     1
# Age
# <35       0.45  0.55
# >35       0.48  0.52

# %% [markdown]
# Employment rates are relatively similar across age groups, with a modest advantage for participants under 35. This suggests that age alone may not be a strong determinant of employment status in the dataset.

# %% [markdown]
# ## Education Level

# %%
edlevel_dist = round(df.EdLevel.value_counts(normalize=True) *100,2).plot.pie(
    autopct="%1.1f%%",
    startangle=90
)
plt.title("Employment Status Distribution")
plt.ylabel("") 
plt.show()

# %% [markdown]
# This distribution indicates that the dataset is heavily concentrated around undergraduate and master’s degree holders, with doctoral-level education being relatively rare among respondents.

# %% [markdown]
# ## Country

# %%
country_counts = df.Country_ISO3.value_counts().reset_index()
country_counts.columns = ["Country","Count"]

# Use a renderer compatible with classic Jupyter notebooks
pio.renderers.default = "notebook_connected"
# Plot the distribution of participants 
fig = px.choropleth(
    country_counts,
    locations="Country",
    locationmode="ISO-3",
    color="Count",
    title="Distribution of Survey Participants by Country",
    color_continuous_scale="Reds"
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="a3899e1a-08b5-4571-9ffa-b3b31ee5836b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a3899e1a-08b5-4571-9ffa-b3b31ee5836b")) {                    Plotly.newPlot(                        "a3899e1a-08b5-4571-9ffa-b3b31ee5836b",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country=%{location}\u003cbr\u003eCount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"ISO-3","locations":["USA","DEU","IND","GBR","CAN","FRA","BRA","POL","NLD","ESP","AUS","ITA","SWE","RUS","CHE","TUR","AUT","ISR","CZE","MEX","BEL","DNK","UKR","NOR","ARG","IRN","FIN","PAK","ZAF","PRT","ROU","GRC","NZL","HUN","COL","BGD","JPN","BGR","CHN","IDN","IRL","SVN","NGA","SRB","EGY","PHL","LKA","CHL","HRV","LTU","TWN","SGP","SVK","MYS","VNM","KOR","KEN","EST","NPL","URY","THA","BLR","HKG","PER","ARE","GEO","VEN","DOM","MAR","LVA","ECU","BIH","CRI","ARM","TUN","SAU","GTM","KAZ","PRY","ALB","GHA","LUX","MKD","LBN","JOR","CYP","ETH","AZE","BOL","UGA","MDA","UZB","MLT","CUB","ISL","SLV","PAN","TZA","SYR","IRQ","MMR","HND","MUS","CMR","MNE","SDN","NIC","DZA","ZWE","RWA","KGZ","MDG","KHM","KWT","AFG","CIV","JAM","MNG","TTO","ZMB","SEN","MDV","AND","BHR","QAT","COD","YEM","NAM","BEN","TKM","COG","AGO","OMN","MOZ","BWA","MWI","TJK","SWZ","GUY","IMN","BRB","LAO","TGO","LBY","SOM","MLI","LSO","SUR","BLZ","GIN","BTN","CPV","TLS","NER","FJI","HTI","LCA","MCO","DMA","KNA","LBR","DJI","VCT","GMB","MRT","BFA","BDI","SYC"],"name":"","z":{"dtype":"i2","bdata":"..."},"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth ...

# %%
#Top 10 Countries
top_10_df = round(df.Country.value_counts(normalize=True,ascending=False).head(10)*100,2).reset_index()
top_10_df
# Out:
#                                              Country  proportion
# 0                           United States Of America       20.02
# 1                                            Germany        7.35
# 2                                              India        7.29
# 3  United Kingdom Of Great Britain And Northern I...        6.38
# 4                                             Canada        3.78
# 5                                             France        3.61
# 6                                             Brazil        3.58
# 7                                             Poland        2.62
# 8                                        Netherlands        2.40
# 9                                              Spain        2.33

# %% [markdown]
# The survey is heavily dominated by participants from a few countries.
# The **United States** alone accounts for 20.0% of respondents.
# Other top countries include **Germany** (7.35%), **India** (7.29%), and the **United Kingdom** (6.38%).
# The remaining countries in the top 10 each contribute between 2.3% and 3.8% of respondents.

# %% [markdown]
# ## Employment

# %%
df.Employment.value_counts(normalize=True)
# Out:
# Employment
# 1    0.883139
# 0    0.116861
# Name: proportion, dtype: float64
